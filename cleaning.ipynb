# %%
import pandas as pd

# %%
df = pd.read_csv("messages.csv")
df
# Out:
#                                         CONVERSATION ID CONVERSATION TITLE  \
# 0     2-MTFkMzEzNmMtZjNlNy00MjI4LWJkZGMtNTRkYWIyYTY5...                NaN
# 1     2-MTFkMzEzNmMtZjNlNy00MjI4LWJkZGMtNTRkYWIyYTY5...                NaN
# 2     2-MTFkMzEzNmMtZjNlNy00MjI4LWJkZGMtNTRkYWIyYTY5...                NaN
# 3     2-MTFkMzEzNmMtZjNlNy00MjI4LWJkZGMtNTRkYWIyYTY5...                NaN
# 4     2-MTFkMzEzNmMtZjNlNy00MjI4LWJkZGMtNTRkYWIyYTY5...                NaN
# ...                                                 ...                ...
# 3599  2-OWIyZTY0ZWMtYjM1Zi00MjRhLTk4NDctMmM3MDE1Njk5...                NaN
# 3600  2-MzZjNTViNTctMDMwMi01ZjJhLWExMWQtNWJiMjU1Y2Fl...                NaN
# 3601  2-YWI1Y2I0ZDItNjVhMS00NmYwLTk4YmMtN2NiYWNiNTE4...                NaN
# 3602  2-YWI1Y2I0ZDItNjVhMS00NmYwLTk4YmMtN2NiYWNiNTE4...                NaN
# 3603  2-YWI1Y2I0ZDItNjVhMS00NmYwLTk4YmMtN2NiYWNiNTE4...                NaN
#
#                           FROM  \
# 0           Praneeth Korukonda
# ...

# %%
df = df[['FROM', 'TO', 'CONTENT']]

# %%
df
# Out:
#                           FROM                  TO  \
# 0           Praneeth Korukonda   Arnab Chakraborty
# 1            Arnab Chakraborty  Praneeth Korukonda
# 2            Arnab Chakraborty  Praneeth Korukonda
# 3           Praneeth Korukonda   Arnab Chakraborty
# 4           Praneeth Korukonda   Arnab Chakraborty
# ...                        ...                 ...
# 3599           LinkedIn Member  Praneeth Korukonda
# 3600  Jill @ LinkedIn Learning  Praneeth Korukonda
# 3601           Sorcha Mulligan  Praneeth Korukonda
# 3602           Sorcha Mulligan  Praneeth Korukonda
# 3603           Sorcha Mulligan  Praneeth Korukonda
#
#                                                 CONTENT
# 0     thats great thanks for letting me know, i will...
# 1                 but Ill be coming this monday as well
# 2                                I come every thursday
# 3     When are you visiting office, only connect wee...
# 4                     Yeah sure, we can do that, thanks
# ...

# %%
df.to_csv('messages1.csv')
